# %% [markdown]
# <a href="https://colab.research.google.com/github/subhamghimire/Machine-Learning/blob/master/pandas_vis_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b',c='red',figsize=(12,3))

# %%
df3['a'].plot.hist()

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(alpha=0.5,bins=25)

# %%
df3[['a','b']].plot.box()

# %%
df3['d'].plot.kde()

# %%
df3['d'].plot.density(lw=5,ls='--')

# %%
df3.iloc[0:30].plot.area(alpha=0.4)
